# %%
#web scrapping using bs4 
#and storing in database using pandas

# %%
import requests
wiki_links = "https://www.thethings.com/fastest-cars-in-2020-that-arent-supercars/"
link = requests.get(wiki_links).text

# %%
print(link)
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
#     <script>
#         // GLOBAL JS VARIABLES FOR THE PAGE
#         var VALNET_GLOBAL_FBAPPID = "1704776379798523";
#         // GLOBAL JS VARIABLES FOR GOOGLE ANALYTICS
#                     var VALNET_GLOBAL_GOOGLEANALYTICSPROPERTYID = "UA-35624077-21";
#             var VALNET_GLOBAL_POSTID = "619142";
#             var VALNET_GLOBAL_AUTHOR = "j_harper";
#             var VALNET_GLOBAL_CHANNEL = "cars-and-trucks";
#             var VALNET_GLOBAL_VIEW = "all";
#             var VALNET_GLOBAL_EXACTVIEW = "all";
#             var VALNET_GLOBAL_ISPREMIUM = "false";
#             var VALNET_GLOBAL_ENVIRONMENT = "native";
#             var VALNET_GLOBAL_POSTTYPE = "list-article";
#             var VALNET_GLOBAL_JREDITOR = "";
#             var VALNET_GLOBAL_SREDITOR = "";
#             var VALNET_GLOBAL_NUMBERPERPAGE = "all";
#             var VALNET_GLOBAL_ISENGAGEMENTTEST = "false";
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(link, 'lxml')
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
# <script>
#         // GLOBAL JS VARIABLES FOR THE PAGE
#         var VALNET_GLOBAL_FBAPPID = "1704776379798523";
#         // GLOBAL JS VARIABLES FOR GOOGLE ANALYTICS
#                     var VALNET_GLOBAL_GOOGLEANALYTICSPROPERTYID = "UA-35624077-21";
#             var VALNET_GLOBAL_POSTID = "619142";
#             var VALNET_GLOBAL_AUTHOR = "j_harper";
#             var VALNET_GLOBAL_CHANNEL = "cars-and-trucks";
#             var VALNET_GLOBAL_VIEW = "all";
#             var VALNET_GLOBAL_EXACTVIEW = "all";
#             var VALNET_GLOBAL_ISPREMIUM = "false";
#             var VALNET_GLOBAL_ENVIRONMENT = "native";
#             var VALNET_GLOBAL_POSTTYPE = "list-article";
#             var VALNET_GLOBAL_JREDITOR = "";
#             var VALNET_GLOBAL_SREDITOR = "";
#             var VALNET_GLOBAL_NUMBERPERPAGE = "all";
#             var VALNET_GLOBAL_ISENGAGEMENTTEST = "false";
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <script>
#    // GLOBAL JS VARIABLES FOR THE PAGE
#         var VALNET_GLOBAL_FBAPPID = "1704776379798523";
#         // GLOBAL JS VARIABLES FOR GOOGLE ANALYTICS
#                     var VALNET_GLOBAL_GOOGLEANALYTICSPROPERTYID = "UA-35624077-21";
#             var VALNET_GLOBAL_POSTID = "619142";
#             var VALNET_GLOBAL_AUTHOR = "j_harper";
#             var VALNET_GLOBAL_CHANNEL = "cars-and-trucks";
#             var VALNET_GLOBAL_VIEW = "all";
#             var VALNET_GLOBAL_EXACTVIEW = "all";
#             var VALNET_GLOBAL_ISPREMIUM = "false";
#             var VALNET_GLOBAL_ENVIRONMENT = "native";
#             var VALNET_GLOBAL_POSTTYPE = "list-article";
#             var VALNET_GLOBAL_JREDITOR = "";
#             var VALNET_GLOBAL_SREDITOR = "";
#             var VALNET_GLOBAL_NUMBERPERPAGE = "all";
#             var VALNET_GLOBAL_ISENGAGEMENTTEST = "false";
# ...

# %%
soup.title
# Out:
# <title>20 Fastest Cars In The World In 2020 (That Aren’t Supercars)</title>

# %%
soup.title.string
# Out:
# '20 Fastest Cars In The World In 2020 (That Aren’t Supercars)'

# %%
soup.a
# Out:
# <a href="/" rel="home" title=""></a>

# %%
soup.find_all("a")
# Out:
# [<a href="/" rel="home" title=""></a>,
#  <a href="/category/celebrity/" itemprop="url">Celebrity</a>,
#  <a href="/category/reality-tv/" itemprop="url">Reality TV</a>,
#  <a href="/category/movies-tv/" itemprop="url">Movies&amp;TV</a>,
#  <a href="/category/lifestyle/" itemprop="url">Lifestyle</a>,
#  <a class="icon i-facebook" href="https://www.facebook.com/thethingscom" target="_blank"></a>,
#  <a class="icon i-youtube" href="https://www.youtube.com/channel/UC4qGmRZ7aLOLfVsSdj5Se2A" target="_blank"></a>,
#  <a class="menu-brands-zone icon i-link" href="//www.therichest.com" rel="nofollow" target="_blank">
#  <img alt="TheRichest" class="logo tr" src="/public/build/images/tr-logo-full-colored-light.d769382c.svg"/>
#  <div class="desc">
#                  	Unique lists featuring pop culture, entertainment and crazy facts.
#                  </div>
#  </a>,
#  <a class="menu-brands-zone icon i-link" href="//www.thesportster.com" rel="nofollow" target="_blank">
# ...

# %%
all_link = soup.find_all("a")
for link in all_link:
    print(link.get("href"))
# Out:
# /
# /category/celebrity/
# /category/reality-tv/
# /category/movies-tv/
# /category/lifestyle/
# https://www.facebook.com/thethingscom
# https://www.youtube.com/channel/UC4qGmRZ7aLOLfVsSdj5Se2A
# //www.therichest.com
# //www.thesportster.com
# //www.hotcars.com
# /contributor/
# /
# /contact/
# /terms-of-use/
# /privacy-policy/
# /dmca-take-down-policy/
# /about/
# /press-kit/
# /fact-checking-policy/
# /corrections-policy/
# /ethics-policy/
# /ownership-funding-advertising-policy/
# /
# /category/cars-and-trucks/
# None
# /author/j_harper/
# mailto:?Subject=20 Fastest Cars In The World In 2020 (That Aren’t Supercars)&Body=Check%20this%20out%21%0Ahttps%3A%2F%2Fwww.thethings.com/fastest-cars-in-2020-that-arent-supercars/
# https://www.thethings.com/things-everyone-forgets-about-bmw-and-things-theyre-always-bragging-about/
# https://www.motortrend.com/news/mitsubishi-3000gt-vr4/
# https://www.thethings.com/new-affordable-sports-cars-under-35000-and-ones-under-75000/
# ...

# %%
all_tables = soup.find_all("table")
print(all_tables)
# Out:
# []

# %%
right_table= soup.find('head', class_= 'item-num')
right_table

# %%
r.status_code
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-b1c2b399a521> in <module>
# ----> 1 r.status_code
#
# NameError: name 'r' is not defined
