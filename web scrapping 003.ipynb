# %%
import requests
import lxml
import html5lib
from bs4 import BeautifulSoup

# %%
url = "https://www.clickittech.com/aws/top-10-aws-services/"

# %%
r = requests.get(url)
html = r.content
soup = BeautifulSoup(html,'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US" prefix="og: http://ogp.me/ns#">
#  <head>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta charset="utf-8"/>
#   <!--   <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/sweetalert/1.1.3/sweetalert.min.css"> -->
#   <!--	<link defer rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/google/code-prettify/master/loader/prettify.css"> -->
#   <meta content="948050238658638" property="fb:pages"/>
#   <meta content="fadfbe07aef62449a90d97b1444c9e1e0cc8e8e8239218b0e967932a23cf81f0" name="ahrefs-site-verification"/>
#   <!--    <script src="https://code.jquery.com/jquery-3.2.1.min.js"></script>  -->
#   <script crossorigin="anonymous" integrity="sha256-FgpCb/KJQlLNfOu91ta32o/NMZxltwRo8QtmkMRdAu8=" src="https://code.jquery.com/jquery-3.3.1.min.js">
#   </script>
#   <!-- <script src="https://cdnjs.cloudflare.com/ajax/libs/sweetalert/1.1.3/sweetalert-dev.min.js" async></script> -->
# ...

# %%
title = soup.title.text
title
# Out:
# 'Top 10 AWS services you should know about (2020 Edition) | Clickittech'

# %%
article = soup.find('article')

print(article.prettify())
# Out:
# <article class="post-34720 post type-post status-publish format-standard has-post-thumbnail hentry category-aws tag-aws tag-services odd first last" id="post-34720">
#  <header>
#   <h1>
#    Top 10 AWS services you should know about (2020 Edition)
#   </h1>
#   <div class="header_meta">
#    By
#    <span class="author vcard meta_author">
#     <a class="url fn n" href="https://www.clickittech.com/author/marioerm/" rel="author" title="View all posts by Mario Rosales">
#      Mario Rosales
#     </a>
#    </span>
#    <span class="meta-date">
#     <time class="entry-date" datetime="2020-03-04T11:34:26-06:00">
#      4 March, 2020
#     </time>
#    </span>
#    <span class="meta_categories">
#     <a href="https://www.clickittech.com/aws/" title="View all posts in AWS">
#      AWS
#     </a>
#    </span>
#    <span class="meta_comment">
#     <a href="https://www.clickittech.com/aws/top-10-aws-services/#respond">
#      Leave a comment
#     </a>
#    </span>
#   </div>
# ...

# %%
headline = article.h1.text
print(headline)
# Out:
# Top 10 AWS services you should know about (2020 Edition)

# %%
summary = article.find('div', class_='header_meta').span.text
print(summary)
# Out:
# Mario Rosales
